# %% [markdown]
# EASY

# %%
import tkinter as tk
r = tk.Tk()
r.title("student")
r.geometry("300x200")
#segment 1
label1 = tk.Label(r,text="Regno:").place(x=10,y=10)
e1 = tk.Entry(r).place(x=55,y=10)
#segment 2
label2 = tk.Label(r,text="Name").place(x=10,y=30)
e2 = tk.Entry(r).place(x=55,y=30)
#segment 3
label3 = tk.Label(r,text="Dept").place(x=10,y=50)
e3 = tk.Entry(r).place(x=55,y=50)
#segment 4
label4 = tk.Label(r,text="gender").place(x=10,y=70)
r1 = tk.Radiobutton(r,text="male",value=1).place(x=60,y=70)
r2 = tk.Radiobutton(r,text="female",value=2).place(x=120,y=70)
#segment 5
label5 = tk.Label(r,text="age").place(x=10,y=90)
s1 = tk.Spinbox(r,from_=0,to= 50).place(x=60,y=90)
#segment 6
button2 = tk.Button(r,text="insert").place(x=10,y=120)
button3 = tk.Button(r,text="update").place(x=100,y=120)
button4 = tk.Button(r,text="delete").place(x=10,y=150)
button5 = tk.Button(r,text="select").place(x=100,y=150)
r.mainloop()

# %%
import tkinter as tk
r = tk.Tk()
r.title("Banking")
r.geometry("300x200")
#segment 1
label1 = tk.Label(r,text="custid:").place(x=10,y=10)
e1 = tk.Entry(r).place(x=100,y=10)
#segment 2
label2 = tk.Label(r,text="customer name").place(x=5,y=30)
e2 = tk.Entry(r).place(x=100,y=30)
#segment 3
label3 = tk.Label(r,text="Branch").place(x=10,y=50)
e3 = tk.Entry(r).place(x=100,y=50)
#segment 4
label4 = tk.Label(r,text="account type").place(x=10,y=70)
r1 = tk.Radiobutton(r,text="saving",value=1).place(x=100,y=70)
r2 = tk.Radiobutton(r,text="non saving",value=2).place(x=180,y=70)
#segment 5
label5 = tk.Label(r,text="amount").place(x=10,y=100)
scale = tk.Scale(r,from_ = 10, to = 50,orient =
tk.HORIZONTAL).place(x=100,y=90)
#segment 6
button2 = tk.Button(r,text="insert").place(x=10,y=140)
button3 = tk.Button(r,text="update").place(x=100,y=140)
button4 = tk.Button(r,text="delete").place(x=10,y=170)
button5 = tk.Button(r,text="select").place(x=100,y=170)
r.mainloop()

# %%
import tkinter as tk
r = tk.Tk()
r.title("employee")
r.geometry("300x200")
#segment 1
label1 = tk.Label(r,text="Empid").place(x=10,y=10)
e1 = tk.Entry(r).place(x=100,y=10)
#segment 2
label2 = tk.Label(r,text="Employee Name").place(x=5,y=30)
e2 = tk.Entry(r).place(x=100,y=30)
#segment 3
label3 = tk.Label(r,text="job").place(x=10,y=50)
e3 = tk.Entry(r).place(x=100,y=50)
#segment 4
label4 = tk.Label(r,text="Employee type").place(x=10,y=70)
r1 = tk.Radiobutton(r,text="regular",value=1).place(x=120,y=70)
r2 = tk.Radiobutton(r,text="temporary",value=2).place(x=190,y=70)
#segment 5
label5 = tk.Label(r,text="salary").place(x=10,y=90)
s1 = tk.Spinbox(r,from_=10,to= 50).place(x=100,y=90)
#segment 6
button2 = tk.Button(r,text="insert").place(x=10,y=120)
button3 = tk.Button(r,text="update").place(x=100,y=120)
button4 = tk.Button(r,text="delete").place(x=10,y=150)
button5 = tk.Button(r,text="select").place(x=100,y=150)
r.mainloop()

# %% [markdown]
# HARD

# %%
import tkinter as tk
from tkinter.font import Font
r = tk.Tk()
r.title("Job application")
r.geometry("412x800")
label = tk.Label(r,text="Job application",font=(20)).place(x=140,y=10)
label = tk.Label(r,text="Personal information",fg='red').place(x=10,y=50)
label = tk.Label(r,text="Name").place(x=10,y=80)
name = tk.Entry(r,text="firstname").place(x=70,y=80)
name = tk.Entry(r,text="lastame").place(x=220,y=80)
label2 = tk.Label(r,text="Email").place(x=10,y=110)
email = tk.Entry(r,text="email").place(x=70,y=110)
label2 = tk.Label(r,text="Education").place(x=10,y=140)
menu = tk.StringVar()
menu.set("please choose")
edu = tk.OptionMenu(r,menu,"Btech","Mtech","BSC").place(x=100,y=140)
label3 = tk.Label(r,text="Resume").place(x=10,y=190)
f =tk.Button(r,text="choose file").place(x=100,y=190)
f1 = tk.Entry(r).place(x=170,y=190)
label3 = tk.Label(r,text="Address").place(x=10,y=250)
e1 = tk.Entry(r,width=40).place(x=100,y=250)
e1 = tk.Entry(r,width=40).place(x=100,y=280)
menu = tk.StringVar()
menu.set("select country")
e1 = tk.OptionMenu(r,menu,"India","USA","Canada").place(x=100,y=310)
label3 = tk.Label(r,text="phone number").place(x=10,y=360)
e2 = tk.Entry(r).place(x=100,y=360)
label3 = tk.Label(r,text="what are your hobbies?").place(x=10,y=390)
e2 = tk.Entry(r,width=50).place(x=10,y=410)
label = tk.Label(r,text="Previous/Current employment information",fg='red').place(x=10,y=450)
label3 = tk.Label(r,text="company name").place(x=10,y=470)
e2 = tk.Entry(r).place(x=180,y=470)
label3 = tk.Label(r,text="job title").place(x=10,y=500)
e2 = tk.Entry(r).place(x=180,y=500)
label3 = tk.Label(r,text="how long were you here?").place(x=10,y=530)
e2 = tk.Entry(r).place(x=180,y=530)
label = tk.Label(r,text="Reference#1",font=(10),fg='red').place(x=10,y=560)
label3 = tk.Label(r,text="Name").place(x=10,y=600)
e2 = tk.Entry(r).place(x=180,y=600)
label3 = tk.Label(r,text="Phone").place(x=10,y=630)
e2 = tk.Entry(r).place(x=180,y=630)
label = tk.Label(r,text="Reference#2",font=(10),fg='red').place(x=10,y=660)
label3 = tk.Label(r,text="Name").place(x=10,y=700)
e2 = tk.Entry(r).place(x=180,y=700)
label3 = tk.Label(r,text="Phone").place(x=10,y=730)
e2 = tk.Entry(r).place(x=180,y=730)
btn =tk.Button(r,text="submit",bg="#B22727",fg='white').place(x=150,y=760)
r.mainloop()
